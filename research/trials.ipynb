# %%
## Dataset download 
import gdown
url = "https://drive.google.com/file/d/1gBfjc4cPNRNxeRc-hSfh4GRmG7umkaFu/view?usp=sharing"

file_id = url.split('/')[-2]

prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix + file_id, 'Chest-CT-Scan-data.zip', quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1gBfjc4cPNRNxeRc-hSfh4GRmG7umkaFu
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1gBfjc4cPNRNxeRc-hSfh4GRmG7umkaFu&confirm=t&uuid=f7319110-0d5d-4cfc-9259-09843070b0b1
# To: /Users/yashasuttangi/Developer/MachineLearning/Projects/CancerClassification/Cancer-classification-end-to-end-using-MLFlow-and-DVC/research/Chest-CT-Scan-data.zip
# 100%|██████████| 125M/125M [00:03<00:00, 37.5MB/s]
# 'Chest-CT-Scan-data.zip'

# %%
# Out:
# Downloading dataset mohamedhanyyy/chest-ctscan-images to artifacts/datasets...
# An error occurred while downloading the dataset: module 'kagglehub' has no attribute 'download'

# %%
with open('../config/config.yaml', 'r') as yaml_file:
    content = yaml.safe_load(yaml_file)
    logger.info(f"YAML file: {path_to_yaml} loaded successfully")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 with open('../config/config.yaml', 'r') as yaml_file:
# ----> 2     content = yaml.safe_load(yaml_file)
#       3     logger.info(f"YAML file: {path_to_yaml} loaded successfully")
#
# NameError: name 'yaml' is not defined

# %%
# %pwd
# Out:
# '/Users/yashasuttangi/Developer/MachineLearning/Projects/CancerClassification/Cancer-classification-end-to-end-using-MLFlow-and-DVC/research'
